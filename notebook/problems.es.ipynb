# %% [markdown]
# # Problemas de prueba de hipótesis

# %% [markdown]
# ## Ejercicio 1
#
# Usted es un nutricionista que investiga dos tipos diferentes de dietas para ver si existe una diferencia significativa en la pérdida de peso después de un mes. Eliges dos grupos aleatorios de personas; un grupo sigue la primera dieta y el otro sigue la segunda. Al final del mes, se registra la pérdida de peso (en kg) de cada persona:
#
# | Diet 1 | Diet 2 |
# |:-------|:-------|
# | 2.0 | 3.0 |
# | 2.5 | 3.2 |
# | 3.0 | 3.1 |
# | 2.8 | 2.9 |
# | 2.3 | 2.8 |
# | 2.7 | 3.0 |
# | 2.5 | 3.2 |
#
# Con estos datos se busca responder a la siguiente pregunta: ¿Existe una diferencia significativa en la pérdida de peso promedio entre las personas que siguieron la primera dieta y las que siguieron la segunda dieta?
#
# Para sacar conclusiones, siga los siguientes puntos:
#
# -Enunciar la hipótesis: hipótesis nula y alternativa.
# -Realizar la prueba para comprobar la hipótesis. Puede utilizar la prueba t de Student.
# -Analizar las conclusiones.

# %%
import numpy as np
from scipy import stats

# Creamos los datos como arreglos numéricos
# diet1: pérdidas de peso (kg) con la Dieta 1
# diet2: pérdidas de peso (kg) con la Dieta 2

diet1 = np.array([2.0, 2.5, 3.0, 2.8, 2.3, 2.7, 2.5])
diet2 = np.array([3.0, 3.2, 3.1, 2.9, 2.8, 3.0, 3.2])

# %%
# Calculamos las medias de cada grupo
# Esto nos permite ver una primera comparación descriptiva

print("Media Dieta 1:", diet1.mean())
print("Media Dieta 2:", diet2.mean())
# Out:
# Media Dieta 1: 2.542857142857143
# Media Dieta 2: 3.0285714285714285

# %%
# Realizamos la prueba t para muestras independientes

t_stat, p_value = stats.ttest_ind(diet1, diet2, equal_var=False)

print("Estadístico t:", t_stat) # Que tan separadas están las medias
print("p-value:", p_value) # Que tan probable es esa diferencia si no hubiera efecto real
# Out:
# Estadístico t: -3.5383407969933938
# p-value: 0.007125697852423994

# %%
# Nivel de Significancia.
alpha = 0.05 # es el 5 %.

# %%
if p_value < alpha:
    print(f"Como p-value ({p_value:.4f}) es menor que (<) alpha ({alpha}). Rechazamos H0.")
    print("Conclusión: Hay diferencia significativa en la pérdida de peso promedio entre dietas.")
else:
    print(f"Como p-value ({p_value:.4f}) es mayor que (>) alpha ({alpha}). No Rechazamos H0.")
    print("Conclusión: No hay evidencia suficiente de diferencia significativa entre dietas.")
# Out:
# Como p-value (0.0071) es menor que (<) alpha (0.05). Rechazamos H0.
# Conclusión: Hay diferencia significativa en la pérdida de peso promedio entre dietas.

# %% [markdown]
# ## ANOVA
#
# **ANOVA** (*Analysis of Variance - Análisis de variación*) Es una técnica estadística utilizada para comparar las medidas de dos o más grupos. La idea detrás de ANOVA es descomponer la variabilidad total de los datos en dos componentes: variabilidad entre grupos y variabilidad dentro de los grupos:
#
# - **Variabilidad entre grupos**: Esta variabilidad se refiere a las diferencias entre las medias del grupo. Si esta variabilidad es considerablemente mayor que la variabilidad dentro del grupo, podría ser una indicación de que al menos una de las medias del grupo es diferente.
# - **Variabilidad dentro del grupo**: Esta variabilidad se refiere a la dispersión de los datos dentro de cada grupo. Si todos los grupos tienen una variabilidad similar, entonces cualquier diferencia notable en las medias de los grupos podría considerarse significativa.
#
# Las hipótesis en ANOVA suelen incluir:
#
# - **Hipótesis nula** ($H₀$): Las medias de todos los grupos son iguales.
# - **Hipótesis alternativa** ($H₁$): Al menos una de las medias del grupo es diferente.
#
# Si el resultado de la prueba ANOVA es significativo (por ejemplo, un valor p inferior a un umbral como 0,05), esto sugiere que al menos la media de un grupo es diferente.

# %% [markdown]
# ## Ejercicio 2
#
# Un agricultor decide probar tres tipos diferentes de fertilizantes para determinar si alguno es superior en términos de producción de maíz. El agricultor planta maíz en 15 parcelas idénticas y utiliza los tres fertilizantes (5 parcelas para cada tipo). Al final de la temporada mide el rendimiento de maíz (en kg) de cada parcela, con el siguiente resultado:
#
# | Fertilizante 1 | Fertilizante 2 | Fertilizante 3 |
# |:-------------|:-------------|:-------------|
# | 20 | 22 | 24 |
# | 21 | 21 | 23 |
# | 20 | 23 | 22 |
# | 19 | 22 | 23 |
# | 20 | 21 | 24 |
#
# Con estos datos busca responder la siguiente pregunta: ¿Existe una diferencia significativa en el rendimiento promedio del maíz entre los tres tipos de fertilizantes?
#
# Para ayudarte, sigue los siguientes puntos:
#
# -Enunciar la hipótesis: hipótesis nula y alternativa.
# -Realizar la prueba ANOVA.
# -Analizar las conclusiones.
# -Si un fertilizante es mejor que otro, ¿cómo podemos saberlo?

# %%
# 1) Datos: rendimiento (kg) de cultivos con cada fertilizante

f1 = np.array([20, 21, 20, 19, 20])
f2 = np.array([22, 21, 23, 22, 21])
f3 = np.array([24, 23, 22, 23, 24])

# %%
# 2) Definimos el nivel de significancia
alpha = 0.05

# %%
# 3) Calculamos medias para tener una idea descriptiva inicial

mean_f1 = np.mean(f1)
mean_f2 = np.mean(f2)
mean_f3 = np.mean(f3)

print("\n=== Medias de rendimiento ===")
print(f"F1: {mean_f1:.2f} kg")
print(f"F2: {mean_f2:.2f} kg")
print(f"F3: {mean_f3:.2f} kg")
# Out:
# === Medias de rendimiento ===
# F1: 20.00 kg
# F2: 21.80 kg
# F3: 23.20 kg

# %%
# 4) ANOVA
# Esta función compara las tres medias al mismo tiempo

F_stat, p_value = stats.f_oneway(f1, f2, f3)

print("Estadístico F:", F_stat) 
print("p-value:", p_value)
# Out:
# Estadístico F: 20.31578947368421
# p-value: 0.00014047824793190402

# %%
# 5) Tomamos una decisión:
# Si p-value < alpha: rechazamos H0
if p_value < alpha:
    print(f"Como p-value ({p_value:.6f}) < alpha ({alpha}), RECHAZAMOS H0.")
    print("Conclusión: Existe diferencia significativa en el rendimiento promedio entre fertilizantes.")
else:
    print(f"Como p-value ({p_value:.6f}) >= alpha ({alpha}), NO rechazamos H0.")
    print("Conclusión: No hay evidencia suficiente de diferencia significativa entre fertilizantes.")
# Out:
# Como p-value (0.000140) < alpha (0.05), RECHAZAMOS H0.
# Conclusión: Existe diferencia significativa en el rendimiento promedio entre fertilizantes.

# %%
from statsmodels.stats.multicomp import pairwise_tukeyhsd
# 1) Unimos los datos en un solo vector y creamos etiquetas de grupo
data = np.concatenate([f1, f2, f3])
groups = (["F1"] * len(f1)) + (["F2"] * len(f2)) + (["F3"] * len(f3))

# 2) Tukey HSD: compara todos los pares controlando el error por comparaciones múltiples
tukey = pairwise_tukeyhsd(endog=data, groups=groups, alpha=0.05)

"""
Si reject = True: ese par sí es diferente de forma significativa.
Si reject = False: ese par no se diferencia significativamente.
"""

print(tukey)
# Out:
# Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ...
# group1 group2 meandiff p-adj  lower  upper  reject
# --------------------------------------------------
#     F1     F2      1.8 0.0099 0.4572 3.1428   True
#     F1     F3      3.2 0.0001 1.8572 4.5428   True
#     F2     F3      1.4 0.0409 0.0572 2.7428   True
# --------------------------------------------------

# %%
# El mejor en términos de promedio es el que tenga la media más alta:
best = max([("F1", mean_f1), ("F2", mean_f2), ("F3", mean_f3)], key=lambda x: x[1])
print(f"\nMejor fertilizante por promedio: {best[0]} con {best[1]:.2f} kg.")
# Out:
# Mejor fertilizante por promedio: F3 con 23.20 kg.
